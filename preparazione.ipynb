# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
data_path = ("/Users/stefanopepe/Desktop/heart_failure_clinical_records_dataset.train.csv")

# %%
heart_failure_clinical_records_dataset=pd.read_csv(data_path)

# %%
heart_failure_clinical_records_dataset.head()
# Out:
#    DEATH_EVENT     age  anaemia  creatinine_phosphokinase  diabetes  \
# 0            1  75.000        1                       246         0
# 1            1  75.000        0                        99         0
# 2            1  60.667        1                       104         1
# 3            0  52.000        0                       132         0
# 4            1  94.000        0                       582         1
#
#    ejection_fraction  high_blood_pressure  platelets  serum_creatinine  \
# 0                 15                    0  127000.00              1.20
# 1                 38                    1  224000.00              2.50
# 2                 30                    0  389000.00              1.50
# 3                 30                    0  218000.00              0.70
# 4                 38                    1  263358.03              1.83
#
#    serum_sodium  sex  smoking  time
# 0           137    1        0    10
# 1           134    1        0   162
# ...

# %%
heart_failure_clinical_records_dataset
# Out:
#      DEATH_EVENT     age  anaemia  creatinine_phosphokinase  diabetes  \
# 0              1  75.000        1                       246         0
# 1              1  75.000        0                        99         0
# 2              1  60.667        1                       104         1
# 3              0  52.000        0                       132         0
# 4              1  94.000        0                       582         1
# ..           ...     ...      ...                       ...       ...
# 234            0  60.667        1                       151         1
# 235            0  58.000        0                       582         1
# 236            0  55.000        0                       748         0
# 237            0  44.000        0                       582         1
# 238            0  80.000        0                       898         0
#
#      ejection_fraction  high_blood_pressure  platelets  serum_creatinine  \
# ...

# %%
r = csv.reader(open("/Users/stefanopepe/Desktop/heart_failure_clinical_records_dataset.train.csv")) 
lines = list(r)

# %%
writer = csv.writer(open("/Users/stefanopepe/Desktop/heart_failure_clinical_records_dataset.output.csv", "w")) 
writer.writerows(lines)

# %%
df.to_csv("test.csv", index=False)

# %%
df.to_csv("train.csv", index=False)
